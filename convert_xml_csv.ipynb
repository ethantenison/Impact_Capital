# %% [markdown]
# # I need to convert XML files to csv

# %%
import pandas as pd
import xml.etree.ElementTree as et
index = pd.read_csv('data/index_2017.csv')

# %% [markdown]
# # Clean IRS 2017 index that is found on the website  https://s3.amazonaws.com/irs-form-990/index_2017.csv to subset
#
# * How are the object IDs created? It looks like they are used for multiple filings.

# %%
#create a column that contains the file names 
index["filename"] = index["OBJECT_ID"].astype(str) + '_public.xml'
print(index.info())
index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489013 entries, 0 to 489012
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   RETURN_ID      489013 non-null  int64
#  1   FILING_TYPE    489013 non-null  object
#  2   EIN            489013 non-null  int64
#  3   TAX_PERIOD     489013 non-null  int64
#  4   SUB_DATE       489013 non-null  object
#  5   TAXPAYER_NAME  489013 non-null  object
#  6   RETURN_TYPE    489013 non-null  object
#  7   DLN            489013 non-null  int64
#  8   OBJECT_ID      489013 non-null  int64
#  9   filename       489013 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 37.3+ MB
# None
#         RETURN_ID FILING_TYPE        EIN  TAX_PERIOD                SUB_DATE  \
# 0        14054169       EFILE   42662873      201603    1/4/2017 10:27:37 AM
# 1        14056200       EFILE   42964630      201512     1/4/2017 8:17:38 PM
# ...

# %%
#Save just a list of the file names 
filenames = index[['filename']]

#for some reason when I try to save it as a .txt file it changes some digits to zero! So what I did was save it as a csv, copy and paste the column into notepad and save
filenames.to_csv(r'data/filenames_990_2017.csv', header=None, index=None, sep=' ', mode='a')

#At this point I run the batch file to move all of the files to a 2017 only file.

# %% [markdown]
# # Here is the batch file I created to move the files, next time try without 'type
# set Source=C:\Users\tenis\OneDrive\Desktop\Data_Projects\Impact_Capital\data\IRS990_2017_2016
# set Target=C:\Users\tenis\OneDrive\Desktop\Data_Projects\Impact_Capital\data\IRS990_2017
# set FileList=C:\Users\tenis\OneDrive\Desktop\Data_Projects\Impact_Capital\data\filenames_990_2017.txt
# echo.
#
# if not exist "%Source%" echo Source folder "%Source%" not found & goto Exit
# if not exist "%FileList%" echo File list "%FileList%" not found & goto Exit
# if not exist "%Target%" md "%Target%"
#
# for /F "delims=" %%a in ('type "%FileList%"') do copy "%Source%\%%a" "%Target%"
#
# :Exit
# echo.
# echo press the Space Bar to close this window.
# pause > nul

# %% [markdown]
# # Fields to pull from IRS 990

# %%
-ein 
-name

FederatedCampaignsAmt
MembershipDuesAmt
FundraisingAmt

'{http://www.irs.gov/efile}RelatedOrganizationsAmt': '4211333',
 '{http://www.irs.gov/efile}GovernmentGrantsAmt': '19700000',
 '{http://www.irs.gov/efile}AllOtherContributionsAmt': '1409845',
 '{http://www.irs.gov/efile}TotalContributionsAmt': '25321178',
    
TotalProgramServiceRevenueAmt
# Out:
#   File "<ipython-input-53-61157529378b>", line 1
#     -federadated campaigns
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Function to convert XML files to Python Dictionaries

# %%
from xml.etree import cElementTree as ElementTree

class XmlListConfig(list):
    def __init__(self, aList):
        for element in aList:
            if element:
                # treat like dict
                if len(element) == 1 or element[0].tag != element[1].tag:
                    self.append(XmlDictConfig(element))
                # treat like list
                elif element[0].tag == element[1].tag:
                    self.append(XmlListConfig(element))
            elif element.text:
                text = element.text.strip()
                if text:
                    self.append(text)


class XmlDictConfig(dict):
    '''
    Example usage:

    >>> tree = ElementTree.parse('your_file.xml')
    >>> root = tree.getroot()
    >>> xmldict = XmlDictConfig(root)

    Or, if you want to use an XML string:

    >>> root = ElementTree.XML(xml_string)
    >>> xmldict = XmlDictConfig(root)

    And then use xmldict for what it is... a dict.
    '''
    def __init__(self, parent_element):
        if parent_element.items():
            self.update(dict(parent_element.items()))
        for element in parent_element:
            if element:
                # treat like dict - we assume that if the first two tags
                # in a series are different, then they are all different.
                if len(element) == 1 or element[0].tag != element[1].tag:
                    aDict = XmlDictConfig(element)
                # treat like list - we assume that if the first two tags
                # in a series are the same, then the rest are the same.
                else:
                    # here, we put the list in dictionary; the key is the
                    # tag name the list elements all share in common, and
                    # the value is the list itself 
                    aDict = {element[0].tag: XmlListConfig(element)}
                # if the tag has attributes, add those to the dict
                if element.items():
                    aDict.update(dict(element.items()))
                self.update({element.tag: aDict})
            # this assumes that if you've got an attribute in a tag,
            # you won't be having any text. This may or may not be a 
            # good idea -- time will tell. It works for the way we are
            # currently doing XML configuration files...
            elif element.items():
                self.update({element.tag: dict(element.items())})
            # finally, if there are no child tags and no attributes, extract
            # the text
            else:
                self.update({element.tag: element.text})

# %% [markdown]
# # Subsetting the multilevel python dictionary
# * Each layer is another bracket

# %%
tree = et.parse('data/test/201602159349301240_public.xml')
root = tree.getroot()
#Converting from xml to dictionary
xmldict = XmlDictConfig(root)

#These are the parent keys of the dictionary
xmldict.keys()

#If you want to see the whole file type xmldict, but it is huge, so I've left that to you. 


#Header Information 
ein = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}EIN']
business_name = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}BusinessName']['{http://www.irs.gov/efile}BusinessNameLine1Txt']
city = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}USAddress']['{http://www.irs.gov/efile}CityNm']
state = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}USAddress']['{http://www.irs.gov/efile}StateAbbreviationCd']
filer_list = [[ein, business_name,city, state]]
filer_df = pd.DataFrame(filer_list, columns = ['EIN', 'BusinessName', 'City','State']) 


#Return Data
related = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}RelatedOrganizationsAmt']
gov_grants = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}GovernmentGrantsAmt']
all_other = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}AllOtherContributionsAmt']
total_contri = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}TotalContributionsAmt']
npo_descri = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}MissionDesc']
type_corp = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}TypeOfOrganizationCorpInd']
contribution_list = [[related, gov_grants, all_other, total_contri, npo_descri, type_corp]]
contribution_df = pd.DataFrame(contribution_list, columns = ['RelatedOrganizationsAmt','GovernmentGrantsAmt','AllOtherContributionsAmt','TotalContributionsAmt','MissionDesc','TypeOfOrganizationCorpInd'])



#Concatenating header informatino and contributions
df_990 = pd.concat([filer_df, contribution_df], axis=1, ignore_index=False)
df_990
# Out:
#          EIN               BusinessName        City State  \
# 0  251753030  Consumer Health Coalition  Pittsburgh    PA
#
#   AllOtherContributionsAmt TotalContributionsAmt  \
# 0                  1476893               1480303
#
#                                          MissionDesc TypeOfOrganizationCorpInd
# 0  To inspire consumer movement to enhance access...                         X

# %%
# Out:
# dict_keys(['{http://www.w3.org/2001/XMLSchema-instance}schemaLocation', 'returnVersion', '{http://www.irs.gov/efile}ReturnHeader', '{http://www.irs.gov/efile}ReturnData'])

# %% [markdown]
# # Function to get a list of files in the 990_2017 directory to loop over

# %%
import os

'''
    For the given path, get the List of all files in the directory tree 
'''
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %% [markdown]
# # I created a tiny subset of files to practice building out the dataframe

# %%
dirName = 'data/test';
files = getListOfFiles(dirName)
files
# Out:
# ['data/test\\201602159349301240_public.xml',
#  'data/test\\201602179349301510_public.xml',
#  'data/test\\201602229349300030_public.xml',
#  'data/test\\201602359349100060_public_pf.xml',
#  'data/test\\201602359349300500_public.xml',
#  'data/test\\201731889349301203_public.xml']

# %%
df = pd.DataFrame([])

for file in files:
    tree = et.parse(file)
    root = tree.getroot()
    #Converting from xml to dictionary
    xmldict = XmlDictConfig(root) 
    
    if xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990'] is not None:
        #Header Information 
        ein = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}EIN']
        business_name = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}BusinessName']['{http://www.irs.gov/efile}BusinessNameLine1Txt']
        city = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}USAddress']['{http://www.irs.gov/efile}CityNm']
        state = xmldict['{http://www.irs.gov/efile}ReturnHeader']['{http://www.irs.gov/efile}Filer']['{http://www.irs.gov/efile}USAddress']['{http://www.irs.gov/efile}StateAbbreviationCd']
        filer_list = [[ein, business_name,city, state]]
        filer_df = pd.DataFrame(filer_list, columns = ['EIN', 'BusinessName', 'City','State']) 


        #Return Data
        related = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}RelatedOrganizationsAmt']
        gov_grants = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}GovernmentGrantsAmt']
        all_other = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}AllOtherContributionsAmt']
        total_contri = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}TotalContributionsAmt']
        npo_descri = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}MissionDesc']
        type_corp = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}TypeOfOrganizationCorpInd']
        contribution_list = [[related, gov_grants, all_other, total_contri, npo_descri, type_corp]]
        contribution_df = pd.DataFrame(contribution_list, columns = ['RelatedOrganizationsAmt','GovernmentGrantsAmt','AllOtherContributionsAmt','TotalContributionsAmt','MissionDesc','TypeOfOrganizationCorpInd'])



        #Concatenating header informatino and contributions
        one_row = pd.concat([filer_df, contribution_df], axis=1, ignore_index=False)
        df = df.append(one_row) 
    
    else:
        continue
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-6e770d02e17f> in <module>
#      18
#      19         #Return Data
# ---> 20         related = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}RelatedOrganizationsAmt']
#      21         gov_grants = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}GovernmentGrantsAmt']
#      22         all_other = xmldict['{http://www.irs.gov/efile}ReturnData']['{http://www.irs.gov/efile}IRS990']['{http://www.irs.gov/efile}AllOtherContributionsAmt']
#
# KeyError: '{http://www.irs.gov/efile}RelatedOrganizationsAmt'
